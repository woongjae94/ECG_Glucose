# %%
import numpy as np
import os
from collections import OrderedDict

# %%
X = np.vstack((np.load("sequenced_data_for_VAE_length-160_stride-10_pt1.npy"),
               np.load("sequenced_data_for_VAE_length-160_stride-10_pt2.npy")))

# %%
print(len(X))
print(len(X[0]))
print(X[0])
for i in X[:100]:
    print(len(i))
# Out:
# 83680
# 160
# [0.18723264 0.18896191 0.18047277 0.19037677 0.1910842  0.19092699
#  0.19210604 0.18738985 0.19595759 0.19312788 0.19800127 0.19886591
#  0.19737245 0.1987087  0.19910172 0.20177422 0.20688342 0.20790527
#  0.20790527 0.21018476 0.21034196 0.21073498 0.20798387 0.19084839
#  0.18503176 0.18086579 0.19407112 0.20232444 0.20680482 0.20263886
#  0.19823708 0.19988775 0.19650781 0.19815848 0.19721524 0.20098819
#  0.20059517 0.19304927 0.18801867 0.18982655 0.19014096 0.18408852
#  0.18235925 0.19697943 0.19242045 0.19705803 0.20193143 0.1961934
#  0.20483974 0.18746845 0.19910172 0.19092699 0.19745105 0.19800127
#  0.196272   0.19839429 0.19768686 0.18951213 0.2038179  0.19257766
#  0.19477854 0.18951213 0.1886475  0.18495315 0.1861322  0.19139861
#  0.19273486 0.19187023 0.19595759 0.20090959 0.20067378 0.19493575
#  0.18849029 0.19517156 0.20051657 0.19957333 0.20035937 0.19029817
#  0.19422832 0.19965194 0.19580038 0.20043797 0.20075238 0.20153841
# ...
